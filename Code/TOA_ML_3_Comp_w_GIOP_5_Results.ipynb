# %% [markdown]
# In this notebook, I compare model outputs for re-run where datasets were split such that the test set corresponded to a subset of data appropriate as input for the GIOP model, the output of which I previously stored in a pandas_dataframe.
# The compared quantity is $aphy(\lambda)$ which from this dataframe is obtained as:
#     $$aph\_\lambda = apg\_\lambda - adg\_\lambda$$

# %%
import pickle

import pandas as pd
import numpy as np
import seaborn as sb
from sklearn.metrics import mean_absolute_error, r2_score
import arviz as az
import matplotlib.pyplot as pl
from matplotlib import cm
from matplotlib.colors import Normalize

from notebook_utils import latexify

# %%
pl.style.use('bmh')

# %%
df_giop_test_set = pd.read_pickle('../PickleJar/DataSets/df_new_test_set.pkl')

# %%
bands = [col.split('_')[1] for col in df_giop_test_set.filter(regex='^rrs')]

# %%
df_aphy_giop = pd.DataFrame(index=df_giop_test_set.index)
for band in bands:
    df_aphy_giop[f'aϕ_{band}'] = df_giop_test_set[f'apg_{band}']\
    - df_giop_test_set[f'adg_{band}']

# %%
df_aphy_giop.sort_index()
# Out:
#        aϕ_412    aϕ_443    aϕ_490    aϕ_510    aϕ_555    aϕ_670
# 45   0.010077  0.013386  0.009206  0.005309  0.001684  0.005260
# 120  0.004476  0.006264  0.004334  0.002287  0.000609  0.002107
# 129  0.007754  0.010902  0.007548  0.003950  0.001036  0.003616
# 135  0.010371  0.014522  0.010048  0.005297  0.001409  0.004877
# 148  0.006316  0.009296  0.006466  0.003133  0.000706  0.002694
# 154  0.006297  0.009128  0.006341  0.003150  0.000746  0.002765
# 172  0.011277  0.015775  0.010914  0.005762  0.001537  0.005313
# 187  0.022373  0.028789  0.019730  0.012010  0.004234  0.012432
# 196  0.005546  0.007863  0.005450  0.002811  0.000716  0.002543
# 200  0.020689  0.027290  0.018753  0.010946  0.003554  0.010950
# 204  0.017437  0.023335  0.016061  0.009147  0.002831  0.008969
# 274  0.014808  0.018589  0.012705  0.008066  0.003088  0.008640
# 274  0.014808  0.018589  0.012705  0.008066  0.003088  0.008640
# 309  0.005064  0.006522  0.004470  0.002717  0.000955  0.002809
# 430  0.012913  0.017852  0.012332  0.006645  0.001845  0.006229

# %%
df_log_aphy_giop = pd.DataFrame(np.log10(df_aphy_giop.values),
                               columns=[f'log10_{col}' for col in df_aphy_giop.columns],
                               index=df_aphy_giop.index)

# %% [markdown]
# Load corresponding test set:

# %%
with open('../PickleJar/DataSets/AphiTrainTestSplitDataSets_4compw_GIOP.pkl',
          'rb') as fb:
    y_test = pickle.load(fb)['y_test']

# %%
y_test.sort_index()
# Out:
#         log10_aphy411  log10_aphy443  log10_aphy489  log10_aphy510  \
# Row_ID
# 45          -1.533429      -1.442493      -1.622330      -1.853562
# 120         -1.773400      -1.721475      -1.918293      -2.168130
# 129         -1.738261      -1.704433      -1.947691      -2.235077
# 135         -1.803824      -1.757459      -2.022276      -2.325139
# 148         -2.103474      -2.008774      -2.226945      -2.542118
# 154         -2.064997      -1.973058      -2.213249      -2.545155
# 172         -2.026410      -1.930702      -2.164944      -2.485452
# 187         -1.481354      -1.341512      -1.507938      -1.728856
# 196         -1.907279      -1.768785      -1.989700      -2.214670
# 200         -1.822752      -1.722849      -1.868061      -2.101275
# 204         -1.634138      -1.521434      -1.646276      -1.822175
# 274         -1.576754      -1.474696      -1.637706      -1.867100
# 309         -1.399899      -1.300249      -1.474566      -1.688882
# 430         -1.846490      -1.762205      -1.953895      -2.219683
#
#         log10_aphy555  log10_aphy670
# Row_ID
# 45          -2.318759      -1.875822
# 120         -2.667562      -2.436519
# 129         -2.829738      -2.563837
# 135         -3.040959      -2.659556
# 148         -3.251812      -2.879426
# 154         -3.366531      -3.017729
# 172         -3.214670      -2.826814
# 187         -2.265200      -1.946922
# 196         -2.749580      -2.411168
# 200         -2.866461      -2.221126
# 204         -2.202040      -2.034798
# 274         -2.352617      -1.852633
# 309         -2.193820      -1.726536
# 430         -2.777284      -2.559091

# %%
df_log_aphy_giop.drop_duplicates().sort_index()
# Out:
#      log10_aϕ_412  log10_aϕ_443  log10_aϕ_490  log10_aϕ_510  log10_aϕ_555  \
# 45      -1.996651     -1.873337     -2.035925     -2.274952     -2.773602
# 120     -2.349082     -2.203115     -2.363070     -2.640785     -3.215194
# 129     -2.110495     -1.962513     -2.122193     -2.403413     -2.984685
# 135     -1.984169     -1.837988     -1.997915     -2.276001     -2.851138
# 148     -2.199540     -2.031713     -2.189344     -2.504063     -3.150922
# 154     -2.200884     -2.039605     -2.197829     -2.501622     -3.127089
# 172     -1.947821     -1.802034     -1.962015     -2.239416     -2.813212
# 187     -1.650278     -1.540768     -1.704872     -1.920457     -2.373199
# 196     -2.256048     -2.104427     -2.263595     -2.551166     -3.144875
# 200     -1.684255     -1.563998     -1.726922     -1.960757     -2.449240
# 204     -1.758532     -1.631990     -1.794224     -2.038731     -2.548114
# 274     -1.829491     -1.730743     -1.896030     -2.093339     -2.510284
# 309     -2.295537     -2.185626     -2.349686     -2.565953     -3.020029
# 430     -1.888984     -1.748305     -1.908969     -2.177509     -2.733953
#
#      log10_aϕ_670
# 45      -2.279003
# 120     -2.676285
# 129     -2.441762
# 135     -2.311803
# 148     -2.569642
# 154     -2.558319
# 172     -2.274661
# 187     -1.905454
# 196     -2.594678
# 200     -1.960588
# 204     -2.047237
# 274     -2.063479
# 309     -2.551503
# 430     -2.205551

# %%
df_log_aphy_giop.rename(columns={'log10_aϕ_490': 'log10_aϕ_489'}, inplace=True)

# %%
df_log_aphy_giop.rename(columns={'log10_aϕ_412': 'log10_aϕ_411'}, inplace=True)

# %%
df_log_aphy_giop.rename(columns={f'{col}': f'{col}_giop'
                                 for col in df_log_aphy_giop.columns},
                       inplace=True)

# %% [markdown]
# ### Comparing GIOP output with bayesian linear regression output

# %%
hs_res_path = '../PickleJar/Results/hshoe_model_dict_2019-07-01 16:15:23.850090.pkl'
with open(hs_res_path, 'rb') as fb:
    hs_res_dict = pickle.load(fb)
bnn_res_path = '../PickleJar/Results/bnn_ARD_1HL_hC_hyp_model_result_2019-07-02 19:33:25.077128.pkl'
with open(bnn_res_path, 'rb') as fb:
    bnn_res_dict = pickle.load(fb)

# %%
hs_res_dict[411]['model'].name
# Out:
# 'hshoe_aphy411'

# %%
bnn_res_dict[411]['model'].name
# Out:
# 'bnn_ARD_1HL_hC_hyp_aphy_411'

# %%
bands = [411, 443, 489, 510, 555, 670]

# %%
def get_test_result(band, res_dict):
    lkl = list(res_dict[band]['ppc_test'].keys())[0]
    ppc_test = res_dict[band]['ppc_test'][lkl]
    return ppc_test
    
def compute_test_stats(test_post, α=0.06):
    tp_mean = test_post.mean(axis=0)
    tp_hpd = az.hpd(test_post, credible_interval=1-α)
    return tp_mean, tp_hpd


def put_all_in_df(band, ppc_test, df_):
    
    post_mean, post_hpd = compute_test_stats(ppc_test)
    df = pd.DataFrame(np.c_[post_mean, post_hpd],
                      columns=[f'log10_aϕ_{band}_pred_mean',
                               f'log10_aϕ_{band}_pred_loCI',
                               f'log10_aϕ_{band}_pred_hiCI'],
                     index=df_.index)
    return df_.merge(df, right_index=True, left_index=True)


df_hs = pd.DataFrame(index=y_test.index)
df_bn = pd.DataFrame(index=y_test.index)
for band in bands:
    pt_hs = get_test_result(band, hs_res_dict)
    pt_bn = get_test_result(band, bnn_res_dict)
    df_hs = put_all_in_df(band, pt_hs, df_hs)
    df_bn = put_all_in_df(band, pt_bn, df_bn)

df_all = pd.merge(df_hs, df_bn, right_index=True, left_index=True,
                 suffixes=('_hs', '_bnn'))
df_all = pd.merge(df_log_aphy_giop, df_all, right_index=True, left_index=True)

df_all.drop_duplicates(inplace=True)

# %%
y_test.rename(columns={f'{col}': f"{col.replace('phy', 'ϕ_')}_True"
                      for col in y_test.columns}, inplace=True)

# %%
y_test
# Out:
#         log10_aϕ_411_True  log10_aϕ_443_True  log10_aϕ_489_True  \
# Row_ID
# 129             -1.738261          -1.704433          -1.947691
# 196             -1.907279          -1.768785          -1.989700
# 135             -1.803824          -1.757459          -2.022276
# 200             -1.822752          -1.722849          -1.868061
# 172             -2.026410          -1.930702          -2.164944
# 45              -1.533429          -1.442493          -1.622330
# 204             -1.634138          -1.521434          -1.646276
# 430             -1.846490          -1.762205          -1.953895
# 274             -1.576754          -1.474696          -1.637706
# 148             -2.103474          -2.008774          -2.226945
# 309             -1.399899          -1.300249          -1.474566
# 120             -1.773400          -1.721475          -1.918293
# 154             -2.064997          -1.973058          -2.213249
# 187             -1.481354          -1.341512          -1.507938
#
#         log10_aϕ_510_True  log10_aϕ_555_True  log10_aϕ_670_True
# Row_ID
# 129             -2.235077          -2.829738          -2.563837
# 196             -2.214670          -2.749580          -2.411168
# 135             -2.325139          -3.040959          -2.659556
# 200             -2.101275          -2.866461          -2.221126
# 172             -2.485452          -3.214670          -2.826814
# 45              -1.853562          -2.318759          -1.875822
# 204             -1.822175          -2.202040          -2.034798
# 430             -2.219683          -2.777284          -2.559091
# 274             -1.867100          -2.352617          -1.852633
# 148             -2.542118          -3.251812          -2.879426
# 309             -1.688882          -2.193820          -1.726536
# 120             -2.168130          -2.667562          -2.436519
# 154             -2.545155          -3.366531          -3.017729
# 187             -1.728856          -2.265200          -1.946922

# %%
df_all = pd.merge(y_test, df_all, right_index=True, left_index=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# UInt64Index: 14 entries, 129 to 187
# Data columns (total 48 columns):
# log10_aϕ_411_True             14 non-null float64
# log10_aϕ_443_True             14 non-null float64
# log10_aϕ_489_True             14 non-null float64
# log10_aϕ_510_True             14 non-null float64
# log10_aϕ_555_True             14 non-null float64
# log10_aϕ_670_True             14 non-null float64
# log10_aϕ_411_giop             14 non-null float64
# log10_aϕ_443_giop             14 non-null float64
# log10_aϕ_489_giop             14 non-null float64
# log10_aϕ_510_giop             14 non-null float64
# log10_aϕ_555_giop             14 non-null float64
# log10_aϕ_670_giop             14 non-null float64
# log10_aϕ_411_pred_mean_hs     14 non-null float64
# log10_aϕ_411_pred_loCI_hs     14 non-null float64
# log10_aϕ_411_pred_hiCI_hs     14 non-null float64
# log10_aϕ_443_pred_mean_hs     14 non-null float64
# log10_aϕ_443_pred_loCI_hs     14 non-null float64
# log10_aϕ_443_pred_hiCI_hs     14 non-null float64
# log10_aϕ_489_pred_mean_hs     14 non-null float64
# log10_aϕ_489_pred_loCI_hs     14 non-null float64
# log10_aϕ_489_pred_hiCI_hs     14 non-null float64
# log10_aϕ_510_pred_mean_hs     14 non-null float64
# log10_aϕ_510_pred_loCI_hs     14 non-null float64
# log10_aϕ_510_pred_hiCI_hs     14 non-null float64
# log10_aϕ_555_pred_mean_hs     14 non-null float64
# log10_aϕ_555_pred_loCI_hs     14 non-null float64
# log10_aϕ_555_pred_hiCI_hs     14 non-null float64
# log10_aϕ_670_pred_mean_hs     14 non-null float64
# log10_aϕ_670_pred_loCI_hs     14 non-null float64
# log10_aϕ_670_pred_hiCI_hs     14 non-null float64
# log10_aϕ_411_pred_mean_bnn    14 non-null float64
# log10_aϕ_411_pred_loCI_bnn    14 non-null float64
# log10_aϕ_411_pred_hiCI_bnn    14 non-null float64
# log10_aϕ_443_pred_mean_bnn    14 non-null float64
# log10_aϕ_443_pred_loCI_bnn    14 non-null float64
# log10_aϕ_443_pred_hiCI_bnn    14 non-null float64
# log10_aϕ_489_pred_mean_bnn    14 non-null float64
# log10_aϕ_489_pred_loCI_bnn    14 non-null float64
# log10_aϕ_489_pred_hiCI_bnn    14 non-null float64
# log10_aϕ_510_pred_mean_bnn    14 non-null float64
# log10_aϕ_510_pred_loCI_bnn    14 non-null float64
# log10_aϕ_510_pred_hiCI_bnn    14 non-null float64
# log10_aϕ_555_pred_mean_bnn    14 non-null float64
# log10_aϕ_555_pred_loCI_bnn    14 non-null float64
# log10_aϕ_555_pred_hiCI_bnn    14 non-null float64
# log10_aϕ_670_pred_mean_bnn    14 non-null float64
# log10_aϕ_670_pred_loCI_bnn    14 non-null float64
# log10_aϕ_670_pred_hiCI_bnn    14 non-null float64
# dtypes: float64(48)
# memory usage: 5.4 KB

# %%
f, axs = pl.subplots(nrows=3, ncols=2, figsize=(14, 20 ))

for band, ax in zip(bands, axs.ravel()):
    vals = df_all[[f'log10_aϕ_{band}_True', f'log10_aϕ_{band}_giop',
                  f'log10_aϕ_{band}_pred_mean_hs',
                  f'log10_aϕ_{band}_pred_mean_bnn']].values
    min_, max_ = vals.min(), vals.max()
        
    mae_giop = mean_absolute_error(df_all[f'log10_aϕ_{band}_True'],
                                   df_all[f'log10_aϕ_{band}_giop'])
    mae_bn = mean_absolute_error(df_all[f'log10_aϕ_{band}_True'],
                                 df_all[f'log10_aϕ_{band}_pred_mean_bnn'])
    df_all.plot.scatter(y=f'log10_aϕ_{band}_True', x=f'log10_aϕ_{band}_giop',
                        ax=ax, color='C0',
                        label=f'GIOP; mae={mae_giop:.2f}', s=70, 
                       edgecolor='k')
    df_all.plot.scatter(y=f'log10_aϕ_{band}_True',
                        x=f'log10_aϕ_{band}_pred_mean_bnn',
                        color='C2', ax=ax,
                        label=f'BNN reg.; mae={mae_bn:.2f}', s=70, alpha=0.75,
                       edgecolor='k')
    ax.set_xlim(min_-.1, max_+.1)
    ax.set_ylim(min_-.1, max_+.1)
    ax.set_ylabel('True', fontsize=16)
    ax.set_xlabel('Prediction', fontsize=16)
    ax.legend(loc='lower right', frameon=True, framealpha=1, fontsize=18)
    ax.plot([min_, max_], [min_, max_], ls='--', color='k');
    ax.set_title(f'aϕ({band})', fontsize=18)

# %%
# For pub. consolidate the above plot into one frame
cmap = cm.get_cmap('gist_yarg')
normalize = Normalize(vmin=min(bands), vmax=max(bands))
colors = [cmap(normalize(value)) for value in bands]
latexify(square=True)
f, ax = pl.subplots()
ax2 = ax.twinx()
#min_, max_ = -2 , -2
for i, band in enumerate(bands):
    mae_giop = mean_absolute_error(df_all[fr'log10_aϕ_{band}_True'],
                                   df_all[fr'log10_aϕ_{band}_giop'])
    mae_bn = mean_absolute_error(df_all[fr'log10_aϕ_{band}_True'],
                                 df_all[fr'log10_aϕ_{band}_pred_mean_bnn'])
    ax.scatter(df_all[f'log10_aϕ_{band}_giop'], df_all[f'log10_aϕ_{band}_True'],
               color=colors[i], edgecolor='k', marker='^',
               label=fr'{band}; mae={mae_giop:.2f}', s=70,)
    ax2.scatter(df_all[f'log10_aϕ_{band}_pred_mean_bnn'],
               df_all[f'log10_aϕ_{band}_True'],
               color=colors[i], edgecolor='k', s=70, alpha=0.75,
               label=fr'{band}; mae={mae_bn:.2f}'
              )
ax.set_xlabel('Prediction')
ax.set_ylabel('True')
mn, mx = -4, -1
ax.plot([mn, mx], [mn, mx], ls='--', color='k');
ax.set_xlim(mn, mx)
ax.set_ylim(mn, mx)
ax2.set_ylim(mn, mx)
ax2.set_yticks([])
#ax2.set_xticks([])
ax.legend(title='GIOP', loc=(0.0, 0.60))
ax2.legend(title='BNN', loc=(0.6, 0));
f.tight_layout()
f.savefig('../FigJar/GIOPBNNcomp.pdf', format='pdf', dpi=300)

# %%
f, axs = pl.subplots(nrows=3, ncols=2, figsize=(17, 15 ))

for i, (band, ax) in enumerate(zip(bands, axs.ravel())):
        
    mae_giop = mean_absolute_error(df_all[f'log10_aϕ_{band}_True'],
                                   df_all[f'log10_aϕ_{band}_giop'])
    mae_hs = mean_absolute_error(df_all[f'log10_aϕ_{band}_True'],
                                 df_all[f'log10_aϕ_{band}_pred_mean_hs'])
    mae_bn = mean_absolute_error(df_all[f'log10_aϕ_{band}_True'],
                                 df_all[f'log10_aϕ_{band}_pred_mean_bnn'])
    y_true = df_all[f'log10_aϕ_{band}_True'].values
    y_giop = df_all[f'log10_aϕ_{band}_giop'].values
    y_bnn = df_all[f'log10_aϕ_{band}_pred_mean_bnn'].values
    idx = np.argsort(y_true)
    y_bnn_hpdlo = df_all[f'log10_aϕ_{band}_pred_loCI_bnn'].values
    y_bnn_hpdhi = df_all[f'log10_aϕ_{band}_pred_hiCI_bnn'].values
    x = np.arange(y_bnn.size)
    ax.fill_between(x, y_bnn_hpdlo[idx], y_bnn_hpdhi[idx], color='k',
                   alpha=0.6)
    ax.scatter(x, y_true[idx], label='true', edgecolor='k', color='C1',
              s=80)
    ax.scatter(x, y_giop[idx], label='GIOP', edgecolor='k', color='C0',
              s=80)
    ax.scatter(x, y_bnn[idx], label='BNN', edgecolor='k', color='C2',
              s=80)
    
    if i in [4, 5]:
        ax.legend(loc='best', framealpha=1, fontsize=16)
        ax.set_xlabel('observation #')
    if i%2>0:
        ax.set_ylabel('aϕ')
    ax.set_title(f'{band}', fontsize=18)
